# %% [markdown]
# #### 문자열 속 문자 찾기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = input()
word = input()

print(data.find(word))
# Out:
# pineapple is yummy
# apple
# 4

# %% [markdown]
# find 는 문자열이 포함되어있는지 확인하고 시작점을 index로 반환해준다.
