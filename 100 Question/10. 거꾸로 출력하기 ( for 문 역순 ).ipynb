# %% [markdown]
# #### 거꾸로 출력하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = input()
# Out:
# 1 2 3 4 5

# %%
l = list(n.split())

# %%
for i in range(len(l)-1 , -1, -1 ):
    print(l[i],end=' ')

# %%
list(range(5, -1 , -1)) # 5에서 -1 까지 -1 간격으로
# Out:
# [5, 4, 3, 2, 1, 0]
