# %% [markdown]
# #### 자동 딕셔너리 만들기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
keys = input(str).split()
values = map(int , input().split())
# Out:
# <class 'str'>Yujin Hyewon
# 70 100

# %%
result = dict(zip(keys , values))

# %%
result
# Out:
# {'Yujin': 70, 'Hyewon': 100}
