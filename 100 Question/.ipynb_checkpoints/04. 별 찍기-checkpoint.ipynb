# %% [markdown]
# ![image.png](attachment:image.png)

# %%
star = int(input())

# %%
for i in range(1,star+1):
    print(" "*(star-i)+("*"*(2*i-1)))
# Out:
#   File "<ipython-input-4-da773eb137e4>", line 2
#     print(" "*(star-i)+"*"*(2*i-1)))
#                                    ^
# SyntaxError: invalid syntax
